# %%
import pandas as pd

# %%
pd.read_csv("Service_Workplace_Injuries.csv")
# Out:
# /tmp/ipykernel_36551/4272992189.py:1: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   pd.read_csv("Service_Workplace_Injuries.csv")
#                ID      UPA EventDate  \
# 0      2015010015   931176    1/1/15
# 1      2015010016   930267    1/1/15
# 2      2015010018   929823    1/1/15
# 3      2015010019   929711    1/1/15
# 4      2015010020   929642    1/1/15
# ...           ...      ...       ...
# 65494  2021064873  1777494   6/15/21
# 65495  2021064874  1777963   6/15/21
# 65496  2021064875  1777595   6/15/21
# 65497  2021064876  1777515   6/15/21
# 65498  2021064878  1777534   6/15/21
#
#                                              Employer  \
# 0      FCI Otisville Federal Correctional Institution
# 1                          Kalahari Manufacturing LLC
# 2                     Schneider National Bulk Carrier
# 3                           PEPSI BOTTLING GROUP INC.
# ...

# %%
import matplotlib.pyplot as plt

# x-coordinates of left sides of bars
left = [1, 2, 3, 4, 5]

# heights of bars
height = [10, 24, 36, 40, 5]

# labels for bars
tick_label = ['Ohio', 'Pennsylvania', 'Flordia', 'Texas', 'Illinois']

# plotting a bar chart
plt.bar(left, height, tick_label = tick_label,
		width = 0.8, color = ['red', 'green'])

# naming the x-axis
plt.xlabel('States')
# naming the y-axis
plt.ylabel('hospitalized')
# plot title
plt.title('TOP FIVE States with the most hospitalizations')

# function to show the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# x-coordinates of left sides of bars
left = [1, 2, 3, 4, 5]

# heights of bars
height = [10000, 12000, 18000, 25000, 2000]

# labels for bars
tick_label = ['Heat burns', 'Lacerations', 'Amputations', 'Fractures', 'Traumatic Injuries']

# plotting a bar chart
plt.bar(left, height, tick_label = tick_label,
		width = 0.2, color = ['blue', 'black'])

# naming the x-axis
plt.xlabel('Injury Types')
# naming the y-axis
plt.ylabel('Number of Cases')
# plot title
plt.title('What are the top five categories of injuries?')

# function to show the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# defining labels
activities = ['Second degree heat burns', 'Amputations', 'Fractures', 'Lacerations']

# portion covered by each label
slices = [3, 7, 8, 6]

# color for each label
colors = ['r', 'y', 'g', 'b']

# plotting the pie chart
plt.pie(slices, labels = activities, colors=colors,
		startangle=90, shadow = True, explode = (0, 0, 0.1, 0),
		radius = 1.2, autopct = '%1.1f%%')

# plotting legend
plt.legend()

# showing the plot
plt.show()
